# %%
import numpy  as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from matplotlib import pyplot
import seaborn as sns
# %matplotlib inline
from statsmodels.tsa.stattools import acf,pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from matplotlib.pylab import rcParams
import itertools

# %%
data =pd.read_csv('data-Hamburgstation.csv')
data.head()
# Out:
#              date     id                                  stid    e5   e10  \
# 0  5/1/2016 21:26   1691  51d4b4ff-a095-1aa0-e100-80009459e03a  1259  1239
# 1  5/1/2016 23:05  22492  51d4b4ff-a095-1aa0-e100-80009459e03a  1319  1299
# 2   5/2/2016 6:17  33677  51d4b4ff-a095-1aa0-e100-80009459e03a  1299  1279
# 3   5/2/2016 9:57  60370  51d4b4ff-a095-1aa0-e100-80009459e03a  1279  1259
# 4  5/2/2016 11:45  71060  51d4b4ff-a095-1aa0-e100-80009459e03a  1269  1249
#
#    diesel  changed
# 0     999       63
# 1    1069       21
# 2    1049       21
# 3    1019       21
# 4    1009       21

# %%
print(data.dtypes)
# Out:
# date       object
# id          int64
# stid       object
# e5          int64
# e10         int64
# diesel      int64
# changed     int64
# dtype: object

# %%
print(data.columns)
# Out:
# Index(['date', 'id', 'stid', 'e5', 'e10', 'diesel', 'changed'], dtype='object')

# %%
from datetime import datetime
con=data['date']
data['date']=pd.to_datetime(data['date'])
data.set_index('date',inplace=True)
data.index
# Out:
# DatetimeIndex(['2016-05-01 21:26:00', '2016-05-01 23:05:00',
#                '2016-05-02 06:17:00', '2016-05-02 09:57:00',
#                '2016-05-02 11:45:00', '2016-05-02 12:37:00',
#                '2016-05-02 14:17:00', '2016-05-02 15:45:00',
#                '2016-05-02 17:45:00', '2016-05-02 23:03:00',
#                ...
#                '2018-10-10 07:24:00', '2018-10-10 08:23:00',
#                '2018-10-10 09:23:00', '2018-10-10 10:23:00',
#                '2018-10-10 11:25:00', '2018-10-10 12:47:00',
#                '2018-10-10 13:53:00', '2018-10-10 17:10:00',
#                '2018-10-10 18:08:00', '2018-10-10 18:56:00'],
#               dtype='datetime64[ns]', name='date', length=12136, freq=None)

# %%
print(data.columns)
# Out:
# Index(['id', 'stid', 'e5', 'e10', 'diesel', 'changed'], dtype='object')

# %%
data.head(100)
# Out:
#                           id                                  stid    e5  \
# date
# 2016-05-01 21:26:00     1691  51d4b4ff-a095-1aa0-e100-80009459e03a  1259
# 2016-05-01 23:05:00    22492  51d4b4ff-a095-1aa0-e100-80009459e03a  1319
# 2016-05-02 06:17:00    33677  51d4b4ff-a095-1aa0-e100-80009459e03a  1299
# 2016-05-02 09:57:00    60370  51d4b4ff-a095-1aa0-e100-80009459e03a  1279
# 2016-05-02 11:45:00    71060  51d4b4ff-a095-1aa0-e100-80009459e03a  1269
# 2016-05-02 12:37:00    83216  51d4b4ff-a095-1aa0-e100-80009459e03a  1289
# 2016-05-02 14:17:00    99575  51d4b4ff-a095-1aa0-e100-80009459e03a  1269
# 2016-05-02 15:45:00   111744  51d4b4ff-a095-1aa0-e100-80009459e03a  1259
# 2016-05-02 17:45:00   122889  51d4b4ff-a095-1aa0-e100-80009459e03a  1259
# %%
print(data.dtypes)
# Out:
# diesel    int64
# dtype: object

# %%
my_plot=data.plot(kind='line',figsize=(15,5))
my_plot.set_xlabel("date")
my_plot.set_ylabel("diesel")
my_plot.legend(["Fuelhistory"])

# %%
data.isnull()
# Out:
#                      diesel
# date
# 2016-05-01 21:26:00   False
# 2016-05-01 23:05:00   False
# 2016-05-02 06:17:00   False
# 2016-05-02 09:57:00   False
# 2016-05-02 11:45:00   False
# 2016-05-02 12:37:00   False
# 2016-05-02 14:17:00   False
# 2016-05-02 15:45:00   False
# 2016-05-02 17:45:00   False
# 2016-05-02 23:03:00   False
# 2016-05-03 06:19:00   False
# 2016-05-03 07:45:00   False
# 2016-05-03 09:44:00   False
# 2016-05-03 10:43:00   False
# 2016-05-03 11:42:00   False
# 2016-05-03 12:34:00   False
# 2016-05-03 14:18:00   False
# 2016-05-03 16:28:00   False
# 2016-05-03 18:43:00   False
# 2016-05-03 23:23:00   False
# 2016-05-04 06:18:00   False
# 2016-05-04 09:02:00   False
# 2016-05-04 09:58:00   False
# 2016-05-04 11:43:00   False
# 2016-05-04 11:58:00   False
# 2016-05-04 12:33:00   False
# 2016-05-04 14:15:00   False
# 2016-05-04 16:28:00   False
# 2016-05-04 16:43:00   False
# 2016-05-04 17:28:00   False
# ...                     ...
# 2018-10-08 10:24:00   False
# 2018-10-08 11:53:00   False
# 2018-10-08 12:46:00   False
# 2018-10-08 13:53:00   False
# 2018-10-08 17:10:00   False
# 2018-10-08 18:09:00   False
# 2018-10-08 18:54:00   False
# 2018-10-08 20:08:00   False
# 2018-10-09 06:32:00   False
# 2018-10-09 07:23:00   False
# 2018-10-09 08:23:00   False
# 2018-10-09 09:52:00   False
# 2018-10-09 11:24:00   False
# 2018-10-09 11:51:00   False
# 2018-10-09 12:46:00   False
# 2018-10-09 13:54:00   False
# 2018-10-09 17:13:00   False
# 2018-10-09 18:08:00   False
# 2018-10-09 18:53:00   False
# 2018-10-10 06:33:00   False
# 2018-10-10 07:24:00   False
# 2018-10-10 08:23:00   False
# 2018-10-10 09:23:00   False
# 2018-10-10 10:23:00   False
# 2018-10-10 11:25:00   False
# 2018-10-10 12:47:00   False
# 2018-10-10 13:53:00   False
# 2018-10-10 17:10:00   False
# 2018-10-10 18:08:00   False
# 2018-10-10 18:56:00   False
#
# [12136 rows x 1 columns]

# %%
data.describe()
# Out:
#              diesel
# count  12136.000000
# mean    1136.883158
# std       74.752121
# min      969.000000
# 25%     1079.000000
# 50%     1129.000000
# 75%     1179.000000
# max     1409.000000

# %%
data=data['2016-5-2':'2018-10-9']
print(data.dtypes)
# Out:
# diesel    int64
# dtype: object

# %%
print(data.index[0],data.index[-1])
# Out:
# 2016-05-02 06:17:00 2018-10-09 18:53:00

# %%
mid=pd.date_range(data.index[0],data.index[-1],freq="H",normalize=True)
mid
# Out:
# DatetimeIndex(['2016-05-02 00:00:00', '2016-05-02 01:00:00',
#                '2016-05-02 02:00:00', '2016-05-02 03:00:00',
#                '2016-05-02 04:00:00', '2016-05-02 05:00:00',
#                '2016-05-02 06:00:00', '2016-05-02 07:00:00',
#                '2016-05-02 08:00:00', '2016-05-02 09:00:00',
#                ...
#                '2018-10-08 15:00:00', '2018-10-08 16:00:00',
#                '2018-10-08 17:00:00', '2018-10-08 18:00:00',
#                '2018-10-08 19:00:00', '2018-10-08 20:00:00',
#                '2018-10-08 21:00:00', '2018-10-08 22:00:00',
#                '2018-10-08 23:00:00', '2018-10-09 00:00:00'],
#               dtype='datetime64[ns]', length=21361, freq='H')

# %%
new_index=mid.union(data.index)
upsampled_data=data.reindex(new_index)
upsampled_data.head(20)
# Out:
#                      diesel
# 2016-05-02 00:00:00     NaN
# 2016-05-02 01:00:00     NaN
# 2016-05-02 02:00:00     NaN
# 2016-05-02 03:00:00     NaN
# 2016-05-02 04:00:00     NaN
# 2016-05-02 05:00:00     NaN
# 2016-05-02 06:00:00     NaN
# 2016-05-02 06:17:00  1049.0
# 2016-05-02 07:00:00     NaN
# 2016-05-02 08:00:00     NaN
# 2016-05-02 09:00:00     NaN
# 2016-05-02 09:57:00  1019.0
# 2016-05-02 10:00:00     NaN
# 2016-05-02 11:00:00     NaN
# 2016-05-02 11:45:00  1009.0
# 2016-05-02 12:00:00     NaN
# 2016-05-02 12:37:00  1029.0
# 2016-05-02 13:00:00     NaN
# 2016-05-02 14:00:00     NaN
# 2016-05-02 14:17:00  1009.0

# %%
upsampled_data.isnull()
# Out:
#                      diesel
# 2016-05-02 00:00:00    True
# 2016-05-02 01:00:00    True
# 2016-05-02 02:00:00    True
# 2016-05-02 03:00:00    True
# 2016-05-02 04:00:00    True
# 2016-05-02 05:00:00    True
# 2016-05-02 06:00:00    True
# 2016-05-02 06:17:00   False
# 2016-05-02 07:00:00    True
# 2016-05-02 08:00:00    True
# 2016-05-02 09:00:00    True
# 2016-05-02 09:57:00   False
# 2016-05-02 10:00:00    True
# 2016-05-02 11:00:00    True
# 2016-05-02 11:45:00   False
# 2016-05-02 12:00:00    True
# 2016-05-02 12:37:00   False
# 2016-05-02 13:00:00    True
# 2016-05-02 14:00:00    True
# 2016-05-02 14:17:00   False
# 2016-05-02 15:00:00    True
# 2016-05-02 15:45:00   False
# 2016-05-02 16:00:00    True
# 2016-05-02 17:00:00    True
# 2016-05-02 17:45:00   False
# 2016-05-02 18:00:00    True
# 2016-05-02 19:00:00    True
# 2016-05-02 20:00:00    True
# 2016-05-02 21:00:00    True
# 2016-05-02 22:00:00    True
# ...                     ...
# 2018-10-08 12:00:00    True
# 2018-10-08 12:46:00   False
# 2018-10-08 13:00:00    True
# 2018-10-08 13:53:00   False
# 2018-10-08 14:00:00    True
# 2018-10-08 15:00:00    True
# 2018-10-08 16:00:00    True
# 2018-10-08 17:00:00    True
# 2018-10-08 17:10:00   False
# 2018-10-08 18:00:00    True
# 2018-10-08 18:09:00   False
# 2018-10-08 18:54:00   False
# 2018-10-08 19:00:00    True
# 2018-10-08 20:00:00    True
# 2018-10-08 20:08:00   False
# 2018-10-08 21:00:00    True
# 2018-10-08 22:00:00    True
# 2018-10-08 23:00:00    True
# 2018-10-09 00:00:00    True
# 2018-10-09 06:32:00   False
# 2018-10-09 07:23:00   False
# 2018-10-09 08:23:00   False
# 2018-10-09 09:52:00   False
# 2018-10-09 11:24:00   False
# 2018-10-09 11:51:00   False
# 2018-10-09 12:46:00   False
# 2018-10-09 13:54:00   False
# 2018-10-09 17:13:00   False
# 2018-10-09 18:08:00   False
# 2018-10-09 18:53:00   False
#
# [33427 rows x 1 columns]

# %%
upsampled_data = upsampled_data.iloc[7:]
upsampled_data.head(100)
# Out:
#                      diesel
# 2016-05-02 06:17:00  1049.0
# 2016-05-02 07:00:00     NaN
# 2016-05-02 08:00:00     NaN
# 2016-05-02 09:00:00     NaN
# 2016-05-02 09:57:00  1019.0
# 2016-05-02 10:00:00     NaN
# 2016-05-02 11:00:00     NaN
# 2016-05-02 11:45:00  1009.0
# 2016-05-02 12:00:00     NaN
# 2016-05-02 12:37:00  1029.0
# 2016-05-02 13:00:00     NaN
# 2016-05-02 14:00:00     NaN
# 2016-05-02 14:17:00  1009.0
# 2016-05-02 15:00:00     NaN
# 2016-05-02 15:45:00   999.0
# 2016-05-02 16:00:00     NaN
# 2016-05-02 17:00:00     NaN
# 2016-05-02 17:45:00   989.0
# 2016-05-02 18:00:00     NaN
# 2016-05-02 19:00:00     NaN
# 2016-05-02 20:00:00     NaN
# 2016-05-02 21:00:00     NaN
# 2016-05-02 22:00:00     NaN
# 2016-05-02 23:00:00     NaN
# 2016-05-02 23:03:00  1069.0
# 2016-05-03 00:00:00     NaN
# 2016-05-03 01:00:00     NaN
# 2016-05-03 02:00:00     NaN
# 2016-05-03 03:00:00     NaN
# 2016-05-03 04:00:00     NaN
# ...                     ...
# 2016-05-04 09:02:00  1039.0
# 2016-05-04 09:58:00  1029.0
# 2016-05-04 10:00:00     NaN
# 2016-05-04 11:00:00     NaN
# 2016-05-04 11:43:00  1019.0
# 2016-05-04 11:58:00  1009.0
# 2016-05-04 12:00:00     NaN
# 2016-05-04 12:33:00  1029.0
# 2016-05-04 13:00:00     NaN
# 2016-05-04 14:00:00     NaN
# 2016-05-04 14:15:00  1009.0
# 2016-05-04 15:00:00     NaN
# 2016-05-04 16:00:00     NaN
# 2016-05-04 16:28:00  1009.0
# 2016-05-04 16:43:00   999.0
# 2016-05-04 17:00:00     NaN
# 2016-05-04 17:28:00   989.0
# 2016-05-04 18:00:00     NaN
# 2016-05-04 19:00:00     NaN
# 2016-05-04 19:43:00   979.0
# 2016-05-04 20:00:00     NaN
# 2016-05-04 21:00:00     NaN
# 2016-05-04 22:00:00     NaN
# 2016-05-04 23:00:00     NaN
# 2016-05-04 23:04:00  1049.0
# 2016-05-05 00:00:00     NaN
# 2016-05-05 01:00:00     NaN
# 2016-05-05 02:00:00     NaN
# 2016-05-05 03:00:00     NaN
# 2016-05-05 04:00:00     NaN
#
# [100 rows x 1 columns]

# %%
upsampled_data = upsampled_data.fillna(method='ffill')

upsampled_data.head(100)
# 2016-05-02 15:45:00     999
# 2016-05-02 16:00:00     999
# 2016-05-02 17:00:00     999
# 2016-05-02 17:45:00     989
# 2016-05-02 18:00:00     989
# 2016-05-02 19:00:00     989

# %%
df.describe()
# Out:
#              diesel
# count  33420.000000
# mean    1137.666068
# std       74.449923
# min      969.000000
# 25%     1089.000000
# 50%     1129.000000
# 75%     1189.000000
# max     1409.000000

# %%
def Plot_ACF_PACF(value):
    lag_acf = acf(value, nlags=50)
    lag_pacf = pacf(value, nlags=50, method='ols')
    plt.subplot(121) 
    plt.plot(lag_acf)
    plt.axhline(y=0,linestyle='--',color='gray')
    plt.axhline(y=-1.96/np.sqrt(len(value)),linestyle='--',color='gray')
    plt.axhline(y=1.96/np.sqrt(len(value,)),linestyle='--',color='gray')
    plt.title('Autocorrelation Function')
    plt.subplot(122)
    plt.plot(lag_pacf)
    plt.axhline(y=0,linestyle='--',color='gray')
    plt.axhline(y=-1.96/np.sqrt(len(value)),linestyle='--',color='gray')
    plt.axhline(y=1.96/np.sqrt(len(value)),linestyle='--',color='gray')
    plt.title('Partial Autocorrelation Function')
    plt.tight_layout()
Plot_ACF_PACF(df.diesel)

# %%
Monthly_data=df['2017-9-2':'2017-9-9']
Monthly_data.head(100)
# Out:
#                      diesel
# 2017-09-02 00:00:00    1149
# 2017-09-02 01:00:00    1149
# 2017-09-02 02:00:00    1149
# 2017-09-02 03:00:00    1149
# 2017-09-02 04:00:00    1149
# 2017-09-02 05:00:00    1149
# 2017-09-02 06:00:00    1149
# 2017-09-02 06:42:00    1139
# 2017-09-02 07:00:00    1139
# 2017-09-02 08:00:00    1139
# 2017-09-02 08:12:00    1129
# 2017-09-02 09:00:00    1129
# 2017-09-02 09:30:00    1089
# 2017-09-02 09:56:00    1079
# 2017-09-02 10:00:00    1079
# 2017-09-02 10:29:00    1079
# 2017-09-02 11:00:00    1079
# 2017-09-02 11:27:00    1069
# 2017-09-02 12:00:00    1069
# 2017-09-02 12:47:00    1099
# 2017-09-02 13:00:00    1099
# 2017-09-02 13:33:00    1089
# 2017-09-02 13:56:00    1069
# 2017-09-02 14:00:00    1069
# 2017-09-02 14:47:00    1059
# 2017-09-02 14:58:00    1059
# 2017-09-02 15:00:00    1059
# 2017-09-02 15:27:00    1059
# 2017-09-02 16:00:00    1059
# 2017-09-02 16:27:00    1049
# ...                     ...
# 2017-09-03 18:00:00    1079
# 2017-09-03 18:21:00    1079
# 2017-09-03 18:28:00    1079
# 2017-09-03 18:46:00    1059
# 2017-09-03 19:00:00    1059
# 2017-09-03 20:00:00    1059
# 2017-09-03 21:00:00    1059
# 2017-09-03 22:00:00    1059
# 2017-09-03 23:00:00    1059
# 2017-09-03 23:01:00    1159
# 2017-09-04 00:00:00    1159
# 2017-09-04 01:00:00    1159
# 2017-09-04 02:00:00    1159
# 2017-09-04 03:00:00    1159
# 2017-09-04 04:00:00    1159
# 2017-09-04 05:00:00    1159
# 2017-09-04 06:00:00    1159
# 2017-09-04 06:18:00    1149
# 2017-09-04 06:45:00    1149
# 2017-09-04 07:00:00    1149
# 2017-09-04 07:41:00    1139
# 2017-09-04 08:00:00    1139
# 2017-09-04 09:00:00    1139
# 2017-09-04 09:36:00    1129
# 2017-09-04 10:00:00    1129
# 2017-09-04 10:13:00    1079
# 2017-09-04 11:00:00    1079
# 2017-09-04 11:29:00    1079
# 2017-09-04 12:00:00    1079
# 2017-09-04 12:48:00    1109
#
# [100 rows x 1 columns]

# %%
my_plot=Monthly_data.plot(kind='line',figsize=(15,5))
my_plot.set_xlabel("date")
my_plot.set_ylabel("diesel")
my_plot.legend(["Fuelhistory"])

# %%
#train=df.loc['2016-05-02':'2018-06-02']
#test=df.loc['2018-06-03':]

# %%
df.head()
# Out:
#                      diesel
# 2016-05-02 06:17:00    1049
# 2016-05-02 07:00:00    1049
# 2016-05-02 08:00:00    1049
# 2016-05-02 09:00:00    1049
# 2016-05-02 09:57:00    1019

# %%
tf=df['diesel']
tf.head()
# Out:
# 2016-05-02 06:17:00    1049
# 2016-05-02 07:00:00    1049
# 2016-05-02 08:00:00    1049
# 2016-05-02 09:00:00    1049
# 2016-05-02 09:57:00    1019
# Name: diesel, dtype: int32

# %%
#split = int(len(tf) / 2)
#print(split)
#X1=X[0:split]
#X2 =X[split:]
#mean1, mean2 = X1.mean(), X2.mean()
#var1, var2 = X1.var(), X2.var()
#print('mean1=%f, mean2=%f' % (mean1, mean2))
#print('variance1=%f, variance2=%f' % (var1, var2))
percent_training=0.95
split_point=round(len(tf)*percent_training)
training,testing=tf[0:split_point],tf[split_point:]

# %%
#Checking the stationery of time series


from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)
    
#Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
  test_stationarity(training)
# Out:
# C:\Users\Bibek\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   if __name__ == '__main__':
# C:\Users\Bibek\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
#   # Remove the CWD from sys.path while we load stuff.
# Results of Dickey-Fuller Test:
# Test Statistic                    -2.621774
# p-value                            0.088580
# #Lags Used                        47.000000
# Number of Observations Used    31701.000000
# Critical Value (1%)               -3.430556
# Critical Value (5%)               -2.861631
# Critical Value (10%)              -2.566819
# dtype: float64

# %%
#from numpy import log
#X=log(tf)
#split = int(len(X) / 2)
#X1=X[0:split]
#X2 =X[split:]
#mean1, mean2 = X1.mean(), X2.mean()
#var1, var2 = X1.var(), X2.var()
#print('mean1=%f, mean2=%f' % (mean1, mean2))
#print('variance1=%f, variance2=%f' % (var1, var2))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition=seasonal_decompose(training,model="additive",filt=None, freq=168)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
fig = decomposition.plot()
fig.set_size_inches(15, 5)

# %%
#training=np.log(training)

# %%
#test_stationarity(training)

# %%
training_Seasonal_difference=training - training.shift(24)
test_stationarity(training_Seasonal_difference.dropna(inplace=False))
# Out:
# C:\Users\Bibek\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   if __name__ == '__main__':
# C:\Users\Bibek\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
#   # Remove the CWD from sys.path while we load stuff.
# Results of Dickey-Fuller Test:
# Test Statistic                   -34.137497
# p-value                            0.000000
# #Lags Used                        49.000000
# Number of Observations Used    31675.000000
# Critical Value (1%)               -3.430556
# Critical Value (5%)               -2.861631
# Critical Value (10%)              -2.566819
# dtype: float64

# %%
#tf_log_diff=tf_log_diff.iloc[1:]
#tf_log_diff=tf_log(periods=1).values[1:]
#tf_log_diff=tf_log - tf_log.shift(24)
#tf_log_diff.head(100)
training_Seasonal_First_difference=training_Seasonal_difference-training_Seasonal_difference.shift(1)

test_stationarity(training_Seasonal_First_difference.dropna(inplace=False))
# Out:
# C:\Users\Bibek\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   if __name__ == '__main__':
# C:\Users\Bibek\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
#   # Remove the CWD from sys.path while we load stuff.
# Results of Dickey-Fuller Test:
# Test Statistic                   -51.887590
# p-value                            0.000000
# #Lags Used                        51.000000
# Number of Observations Used    31672.000000
# Critical Value (1%)               -3.430556
# Critical Value (5%)               -2.861631
# Critical Value (10%)              -2.566819
# dtype: float64

# %%
training_Seasonal_First_difference.dropna(inplace=True)
residual.dropna(inplace=True)

# %%
#tf_log_diff=tf_log_diff.iloc[1:]
training_Seasonal_difference.dropna(inplace=True)
my_plot=training_Seasonal_First_difference.plot(kind='line',figsize=(15,5))
my_plot.set_xlabel("date")
#plt.plot(tf_log_diff)
# Out:
# Text(0.5,0,'date')

# %%
#test_stationarity(tf_log_diff)

# %%
#tf_decompose=residual
#tf_decompose.dropna(inplace=True)
#test_stationarity(tf_decompose)

# %%
#tf.head()

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plot_acf(training_Seasonal_First_difference,lags=100)
#plot_acf(residual,lags=50)
pyplot.show()

# %%
plot_pacf(training_Seasonal_First_difference,lags=100)
pyplot.show()

# %%
#tf.head()
tf_log_diff.head()

# %%
#model = ARIMA(tf_log,order=(1,1,1))  
#results_ARIMA = model.fit(disp=-1)  
#plt.plot(tf_log_diff)
#plt.plot(results_ARIMA.fittedvalues, color='red')
#plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-tf_log_diff)**2))

# %% [markdown]
# ARIMA sumarry and residual plots

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p =range(0,2)
d =range(0,2)
q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 24) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))

# %% [markdown]
# c4=[]
# for param in pdq:
#     for param_seasonal in seasonal_pdq:
#         try:
#             mod = sm.tsa.statespace.SARIMAX(training,
#                                             order=param,
#                                             seasonal_order=param_seasonal,
#                                             enforce_stationarity=False,
#                                             enforce_invertibility=False)
#
#             results = mod.fit()
#
#             print('ARIMA{}x{}24 - AIC:{}'.format(param, param_seasonal, results.aic))
#             c4.append('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
#             c4.append(results.aic)
#         except:
#             continue

# %%
model =sm.tsa.statespace.SARIMAX(training.values,order=(1, 1, 1),
                                seasonal_order=(1, 1, 1, 24),
                                enforce_stationarity=False,
                                enforce_invertibilit=False)

model_fit = model.fit(disp=0)

print(model_fit.summary())

# %%
model_fit.plot_diagnostics(figsize=(15,12))
plt.show()

# %%
print(model_fit)

# %%
K=len(testing)
forecast=model_fit.forecast(K)
forecast=forecast.astype(int)
#forecast=np.exp(forecast)
print(forecast)
#plot forecast results and display RMSE
plt.figure(figsize=(10,5))
#plt.plot(forecast,'r');
plt.plot(tf,'b');
plt.title('RMSE:%.2f'% np.sqrt(sum((forecast-testing)**2)/len(testing)));
plt.xlabel("DateTime");
plt.ylabel("Diese_Price");
plt.autoscale(enable=True,axis='x',tight=True)
plt.axvline(x=tf.index[split_point],color='black');#line separates training/testing

# %%
#predictions_ARIMA_diff=pd.Series(results.fittedvalues,copy=True)
#print (predictions_ARIMA_diff.head(50))

# %% [markdown]
# Scaling back Predictions

# %%
#pred_dynamic = model_fit.get_prediction(start=pd.to_datetime('2018-02-01 00:00:00'), dynamic=True, full_results=True)
#pred_dynamic_ci = pred_dynamic.conf_int()

# %%
#ax = training['2016-05-02':].plot(label='observed', figsize=(20, 15))
#pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)


#ax.set_xlabel('Date')
#ax.set_ylabel('Diesel Price')

#plt.legend()
#plt.show()

# %%
#y_forecasted = pred_dynamic.predicted_mean
#y_truth = training['2016-05-02 00:00:00':]

# Compute the mean square error
#mse = ((y_forecasted - y_truth) ** 2).mean()
#print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))

# %%
#pred_uc = model_fit.forecast(5)

# Get confidence intervals of forecasts
#pred_ci = pred_uc.conf_int()
#We can use the output of this code to plot the time series and forecasts of its future values.

#ax = tf.plot(label='observed', figsize=(20, 15))
#pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
#ax.fill_between(pred_ci.index,
                #pred_ci.iloc[:, 0],
                #pred_ci.iloc[:, 1], color='k', alpha=.25)
#ax.set_xlabel('Date')
#ax.set_ylabel('diesel price')

#plt.legend()
#plt.show()

# %%
#predictions_ARIMA_diff=pd.Series(model_fit.fittedvalues,copy=True)
#print (predictions_ARIMA_diff.head(100))

# %%
#predictions_ARIMA_diff.iloc[0]=predictions_ARIMA_diff.iloc[1]
#predictions_ARIMA_diff.head()

# %%
#predictions_ARIMA = np.exp(predictions_ARIMA_diff)
#predictions_ARIMA.describe()

# %%
#plt.plot(tf)
#plt.plot(predictions_ARIMA)
#plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-tf)**2)/len(tf)))

# %%
#predictions_ARIMA.head(260)

# %%
#X = df.values.astype(float)
#size = int(len(X) * 0.8)
#train, test = X[0:size], X[size:len(X)]
#print(train)
#history = [x for x in train]
#predictions = list()
#for t in range(len(test)):
#	model = ARIMA(history, order=(2,1,2))
#	model_fit = model.fit(disp=0)
#	output = model_fit.forecast()
#	yhat = output[0]
#	predictions.append(yhat)
#	obs = test[t]
#	history.append(obs)
#	#print('predicted=%f, expected=%f' % (yhat, obs))
#error = mean_squared_error(test, predictions)
#print('Test MSE: %.3f' % error)
# plot
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
