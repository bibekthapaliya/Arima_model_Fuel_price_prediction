# %%
import numpy  as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import matplotlib.pyplot as plt1
# %matplotlib inline
import plotly.plotly as py
from plotly.graph_objs import*

# %%
from statsmodels.graphics.api import qqplot

# %%
data=pd.read_csv("Desktop\\Fake.csv")

# %%
data.head()
# Out:
#          Date  Fake
# 0  2016-03-06     5
# 1  2016-03-13     4
# 2  2016-03-20     4
# 3  2016-03-27     5
# 4  2016-04-03     4

# %%
data.head(50)
# Out:
#           Date  Fake
# 0   2016-03-06     5
# 1   2016-03-13     4
# 2   2016-03-20     4
# 3   2016-03-27     5
# 4   2016-04-03     4
# 5   2016-04-10     4
# 6   2016-04-17     4
# 7   2016-04-24     4
# 8   2016-05-01     4
# 9   2016-05-08     5
# 10  2016-05-15     4
# 11  2016-05-22     4
# 12  2016-05-29     3
# 13  2016-06-05     4
# 14  2016-06-12     5
# 15  2016-06-19     5
# 16  2016-06-26     4
# 17  2016-07-03     5
# 18  2016-07-10     5
# 19  2016-07-17     5
# 20  2016-07-24     5
# 21  2016-07-31     4
# 22  2016-08-07     4
# 23  2016-08-14     4
# 24  2016-08-21     4
# 25  2016-08-28     4
# 26  2016-09-04     4
# 27  2016-09-11     4
# 28  2016-09-18     5
# 29  2016-09-25     4
# 30  2016-10-02     6
# 31  2016-10-09     6
# 32  2016-10-16     5
# 33  2016-10-23     6
# 34  2016-10-30     8
# 35  2016-11-06    11
# 36  2016-11-13    43
# 37  2016-11-20    35
# 38  2016-11-27    29
# 39  2016-12-04    48
# 40  2016-12-11    46
# 41  2016-12-18    26
# 42  2016-12-25    23
# 43  2017-01-01    24
# 44  2017-01-08    69
# 45  2017-01-15    42
# 46  2017-01-22    47
# 47  2017-01-29    47
# 48  2017-02-05    48
# 49  2017-02-12    59

# %%
data.plot('Date',figsize=(15,5))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 2 columns):
# Date    108 non-null object
# Fake    108 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.8+ KB

# %%
data.dtypes
# Out:
# Date    object
# Fake     int64
# dtype: object

# %%
data.columns
# Out:
# Index(['Date', 'Fake'], dtype='object')

# %%
from datetime import datetime
con=data['Date']
data['Date']=pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
#check datatype of index
data.index
# Out:
# DatetimeIndex(['2016-03-06', '2016-03-13', '2016-03-20', '2016-03-27',
#                '2016-04-03', '2016-04-10', '2016-04-17', '2016-04-24',
#                '2016-05-01', '2016-05-08',
#                ...
#                '2018-01-21', '2018-01-28', '2018-02-04', '2018-02-11',
#                '2018-02-18', '2018-02-25', '2018-03-04', '2018-03-11',
#                '2018-03-18', '2018-03-25'],
#               dtype='datetime64[ns]', name='Date', length=108, freq=None)

# %%
my_plot=data.plot(kind='line',figsize=(15,5))
my_plot.set_xlabel("Date")
my_plot.set_ylabel("Fake")
my_plot.legend(["Fake"])

# %%
ts=data['Fake']

# %%
ts.head()
# Out:
# Date
# 2016-03-06    5
# 2016-03-13    4
# 2016-03-20    4
# 2016-03-27    5
# 2016-04-03    4
# Name: Fake, dtype: int64

# %%
ts['2016-03-20']
# Out:
# 4

# %%
plt.plot(ts)

# %%
#Checking the stationery of time series


from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)
#Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
test_stationarity(ts)
# Out:
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
#
# pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning:
#
# pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.719783
# p-value                          0.420949
# #Lags Used                       4.000000
# Number of Observations Used    103.000000
# Critical Value (1%)             -3.495493
# Critical Value (5%)             -2.890037
# Critical Value (10%)            -2.581971
# dtype: float64

# %%
#This is not stationary because :

# mean is increasing even though the std is small.

# Test stat is > critical value.

#Note: the signed values are compared and the absolute values.

# %%
ts_log=np.log(ts)
ts_log.plot(figsize=(15,5))

# %%
ts_log.head(20)
# Out:
# Date
# 2016-03-06    1.609438
# 2016-03-13    1.386294
# 2016-03-20    1.386294
# 2016-03-27    1.609438
# 2016-04-03    1.386294
# 2016-04-10    1.386294
# 2016-04-17    1.386294
# 2016-04-24    1.386294
# 2016-05-01    1.386294
# 2016-05-08    1.609438
# 2016-05-15    1.386294
# 2016-05-22    1.386294
# 2016-05-29    1.098612
# 2016-06-05    1.386294
# 2016-06-12    1.609438
# 2016-06-19    1.609438
# 2016-06-26    1.386294
# 2016-07-03    1.609438
# 2016-07-10    1.609438
# 2016-07-17    1.609438
# Name: Fake, dtype: float64

# %%
test_stationarity(ts_log)
# Out:
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
#
# pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning:
#
# pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.742518
# p-value                          0.409350
# #Lags Used                       0.000000
# Number of Observations Used    107.000000
# Critical Value (1%)             -3.492996
# Critical Value (5%)             -2.888955
# Critical Value (10%)            -2.581393
# dtype: float64

# %%
ts_log_diff = ts_log - ts_log.shift(1)
plt.plot(ts_log_diff)

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff)
# Out:
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
#
# pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning:
#
# pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                -8.974101e+00
# p-value                        7.614065e-15
# #Lags Used                     1.000000e+00
# Number of Observations Used    1.050000e+02
# Critical Value (1%)           -3.494220e+00
# Critical Value (5%)           -2.889485e+00
# Critical Value (10%)          -2.581676e+00
# dtype: float64

# %%
#df=data

# %%
ts_log.head()
# Out:
# Date
# 2016-03-06    1.609438
# 2016-03-13    1.386294
# 2016-03-20    1.386294
# 2016-03-27    1.609438
# 2016-04-03    1.386294
# Name: Fake, dtype: float64

# %%
#df.head()
# Out:
#             Fake
# Date
# 2016-03-06     5
# 2016-03-13     4
# 2016-03-20     4
# 2016-03-27     5
# 2016-04-03     4

# %%
#df["FakeShift1"]=df.Fake.shift()

# %%
#df.head()
# Out:
#             Fake  FakeShift1
# Date
# 2016-03-06     5         NaN
# 2016-03-13     4         5.0
# 2016-03-20     4         4.0
# 2016-03-27     5         4.0
# 2016-04-03     4         5.0

# %%
#df["Fakelag1"]=df.Fake-df.FakeShift1

# %%
#df.head()
# Out:
#             Fake  FakeShift1  Fakelag1
# Date
# 2016-03-06     5         NaN       NaN
# 2016-03-13     4         5.0      -1.0
# 2016-03-20     4         4.0       0.0
# 2016-03-27     5         4.0       1.0
# 2016-04-03     4         5.0      -1.0

# %%
#df.Fakelag1.plot(figsize=(15,5))

# %%
#ts=df.Fakelag1

# %%
#df.Fakelag1.dropna(inplace=True)
#test_stationarity(df.Fakelag1)
# Out:
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
#
# pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning:
#
# pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                -8.270116e+00
# p-value                        4.818650e-13
# #Lags Used                     3.000000e+00
# Number of Observations Used    1.030000e+02
# Critical Value (1%)           -3.495493e+00
# Critical Value (5%)           -2.890037e+00
# Critical Value (10%)          -2.581971e+00
# dtype: float64

# %%
#This is  stationary because :

# mean is increasing even though the std is small.

# Test stat is < critical value.

#Note: the signed values are compared and the absolute values.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
#data.head()

# %%
decomposition=seasonal_decompose(ts_log,model="additive")
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
fig = decomposition.plot()
fig.set_size_inches(15, 5)

# %%
ts_log.head()
# Out:
# Date
# 2016-03-06    1.609438
# 2016-03-13    1.386294
# 2016-03-20    1.386294
# 2016-03-27    1.609438
# 2016-04-03    1.386294
# Name: Fake, dtype: float64

# %%
ts_log_decompose = residual
ts_log_decompose.dropna(inplace=True)
test_stationarity(ts_log_decompose)
# Out:
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
#
# pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning:
#
# pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.883874
# p-value                         0.793236
# #Lags Used                      2.000000
# Number of Observations Used    53.000000
# Critical Value (1%)            -3.560242
# Critical Value (5%)            -2.917850
# Critical Value (10%)           -2.596796
# dtype: float64

# %%
ts_log_seasonal_first_difference=ts_log_diff-ts_log_diff.shift(12)
#ts['seasonal_first_difference']=df.Fakelag1-df.Fakelag1.shift(12)
test_stationarity(ts_log_seasonal_first_difference.dropna(inplace=False))
# Out:
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
#
# pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#
# C:\Users\Bvek\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning:
#
# pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.206352
# p-value                         0.019620
# #Lags Used                     11.000000
# Number of Observations Used    83.000000
# Critical Value (1%)            -3.511712
# Critical Value (5%)            -2.897048
# Critical Value (10%)           -2.585713
# dtype: float64

# %%
data.head()
# Out:
#             Fake
# Date
# 2016-03-06     5
# 2016-03-13     4
# 2016-03-20     4
# 2016-03-27     5
# 2016-04-03     4

# %%
df=ts_log
df_diff=ts_log_diff
df_diff.dropna(inplace=True)
df.head()
# Out:
# Date
# 2016-03-06    1.609438
# 2016-03-13    1.386294
# 2016-03-20    1.386294
# 2016-03-27    1.609438
# 2016-04-03    1.386294
# Name: Fake, dtype: float64

# %%
from statsmodels.tsa.stattools import acf, pacf

# %%
lag_acf = acf(df_diff, nlags=20)

# %%
lag_acf
# Out:
# array([ 1.        , -0.15702195, -0.12275548, -0.05682926, -0.03688637,
#         0.09099665,  0.04761177, -0.12113174,  0.09702472, -0.01234038,
#         0.03141591,  0.06609416, -0.13185674,  0.06596415,  0.02221696,
#        -0.07509729,  0.04500655, -0.07720662, -0.0392822 ,  0.07753417,
#        -0.05701654])

# %%
#Plot Acf
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(df_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(df_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5,1,'Autocorrelation Function')

# %%
lag_pacf = pacf(df_diff, nlags=20, method='ols')

# %%
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(df_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(df_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
ts_log.head()
# Out:
# Date
# 2016-03-06    1.609438
# 2016-03-13    1.386294
# 2016-03-20    1.386294
# 2016-03-27    1.609438
# 2016-04-03    1.386294
# Name: Fake, dtype: float64

# %%
ts.head()
# Out:
# Date
# 2016-03-06    1.60944
# 2016-03-13    1.38629
# 2016-03-20    1.38629
# 2016-03-27    1.60944
# 2016-04-03    1.38629
# Name: Fake, dtype: object

# %%
model=ARIMA(df,order=(2, 1, 0))
results_AR=model.fit(display=-1)
results_AR.fittedvalues.head()
# Out:
# Date
# 2016-03-13    0.018731
# 2016-03-20    0.056709
# 2016-03-27    0.058305
# 2016-04-03   -0.015364
# 2016-04-10    0.031805
# dtype: float64

# %%
#AR MODEL
plt.plot(ts_diff)
plt.plot(results_AR.fittedvalues,color='red')
plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-df_diff)**2))
# Out:
# Text(0.5,1,'RSS: 8.9790')

# %%
model = ARIMA(df, order=(0, 1, 2))  
results_MA = model.fit(disp=-1)  
plt.plot(ts_diff)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_MA.fittedvalues-df_diff)**2))
# Out:
# Text(0.5,1,'RSS: 8.6713')

# %%
model = ARIMA(df, order=(2, 1, 2))  
results_ARIMA = model.fit(disp=-1)  
plt.plot(ts_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-df_diff)**2))
# Out:
# Text(0.5,1,'RSS: 8.5974')
